# %% [markdown]
# ## Looping over data files and fitting parameters to torque curve

# %%
from datahandling import DataFile, alldatafiles, cuts, trim
from lmfit import minimize, report_fit
from model_parameters import parameters, parameter_vectors
from curve_func_2 import torque_curve, fcn2min_torque, model_curves
from time import time as tm
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Loading all files

# %%
files = alldatafiles()
no_files = len(files)

# %% [markdown]
# #### Looping over files

# %%
t = tm()
all_ps = []

for i, f in enumerate(files[:1]):
    time_data, temp_data, torque_data = DataFile(f).simple_data()
    
    # Trimming data
    c = cuts(torque_data)
    time_data = trim(time_data, c)
    temp_data = trim(temp_data, c)
    torque_data = trim(torque_data, c)
    
    # Initialising and limiting parameters
    p = parameters()
    
    # Fitting data
    result = minimize(fcn2min_torque, p, args=(time_data, torque_data))
    
    #Storing parameter values
    all_ps = append(all_ps, p)
    print 'Completed Fit ',(i + 1)
    print '__________________________'

elapsed = tm() - t
print '*******************'
print 'elapsed time (min) =', elapsed/60.
# Out:
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Completed Fit
#  1
# __________________________
# *******************
# elapsed time (min) = 0.216533331076

# %% [markdown]
# #### Analysing results

# %%
spec_result = 0
report_fit(all_ps[spec_result], show_correl=False)
# Out:
# [[Variables]]
#      E:               5889.479 +/- 21.60386 (0.37%) initial =  6500
#      UA:              137.2537 +/- 7.437455 (5.42%) initial =  340
#      k1:              2.365582 +/- 0.08589817 (3.63%) initial =  2
#      k10:             2.933245 +/- 391.7419 (13355.24%) initial =  2
#      k11:             7.047176 +/- 0.2190847 (3.11%) initial =  1
#      k2:              10896.49 +/- 278936.7 (2559.88%) initial =  5
#      k3:              0.3376802 +/- 0.01801014 (5.33%) initial =  0.35
#      k4:              0.3107738 +/- 0.01714373 (5.52%) initial =  0.3
#      k5:              0.0009467308 +/- 0.002514623 (265.61%) initial =  0.001
#      k6:              1.217354 +/- 0.03096749 (2.54%) initial =  1
#      k7:              0.1014371 +/- 19.57099 (19293.72%) initial =  0.1
#      k8:              0.07453441 +/- 10.11678 (13573.30%) initial =  0.05
#      k9:              0.0006642725 +/- 0.09687419 (14583.50%) initial =  2
#      mu_0:            0.03760611 +/- 0.001747195 (4.65%) initial =  0.03
#      prim_stab_0:     0.7694502 +/- 0.002143243 (0.28%) initial =  0.7
#      q:               3.550592 +/- 2.22378 (62.63%) initial =  2.5

# %% [markdown]
# #### Generating and plotting all model outputs

# %%
time_data, temp_data, torque_data = DataFile(files[spec_result]).simple_data()

c_1 = cuts(torque_data)
time_data = trim(time_data, c_1)
temp_data = trim(temp_data, c_1)
torque_data = trim(torque_data, c_1)

curves = model_curves(all_ps[spec_result], time_data)

# %%
HCl, LDH, poly_act, radical, prim_stab, deg_poly, x_link, T, Tm, mu, torque = curves

# %%
figure()
plot(time_data, torque, label='fitted torque curve')
plot(time_data, torque_data, label='torque data')
legend()

figure()
plot(time_data, Tm, label='fitted temp curve')
plot(time_data, temp_data, label='temp data')
legend()
xlim([0, 31])

figure()
plot(time_data, HCl, '--', label='HCl')
plot(time_data, LDH, label='LDH')
#plot(time_data, poly_act, '-.', label='poly_act')
plot(time_data, radical, ':', label='radical')
plot(time_data, prim_stab, '--', label='prim_stab')
plot(time_data, deg_poly, label='deg_poly')
plot(time_data, x_link, label='x_link')
legend()
xlim([0, 26])
# Out:
# (0, 26)

# %% [markdown]
# #### Generating parameter vectors and plotting

# %%
para_V = parameter_vectors(all_ps)

# %%
figure_headings = ['k1, visc-torque',
                   'k2, Tm-T',
                   'k3, LDH rxn',
                   'k4, auto-catalytic HCl production rxn',
                   'k5, initiation rxn for HCl production',
                   'k6, primary stabiliser rxn',
                   'k7, radical to degraded polymer',
                   'k8, radical to cross-link',
                   'k9, degraded polymer effect on visc',
                   'k10, cross-linking effect on visc',
                   'k11, mechanical work affecting temp',
                   'UA',
                   'mu_0',
                   'E',
                   'q',
                   'prim_stab_0']

# %%
for h, ps in zip(figure_headings, para_V):
    figure().suptitle(h)
    plot(ps, '.')

# %% [markdown]
# ####Placing parameters into DataFrame

# %%
from pandas import DataFrame

# %%
para_frame = DataFrame.from_records(para_V, index=figure_headings).transpose()

# %% [markdown]
# Mean values of each parameter

# %%
para_frame.mean(axis=0)
# Out:
# k1, visc-torque                              2.365582
# k2, Tm-T                                 10896.492409
# k3, LDH rxn                                  0.337680
# k4, auto-catalytic HCl production rxn        0.310774
# k5, initiation rxn for HCl production        0.000947
# k6, primary stabiliser rxn                   1.217354
# k7, radical to degraded polymer              0.101437
# k8, radical to cross-link                    0.074534
# k9, degraded polymer effect on visc          0.000664
# k10, cross-linking effect on visc            2.933245
# k11, mechanical work affecting temp          7.047176
# UA                                         137.253696
# mu_0                                         0.037606
# E                                         5889.479463
# q                                            3.550592
# prim_stab_0                                  0.769450
# dtype: float64

# %% [markdown]
# Upper boundary values for each parameter = mean + 2.standard deviation

# %%
upper_bounds = para_frame.mean(axis=0) + 2*para_frame.std(axis=0)
upper_bounds
# Out:
# k1, visc-torque                         NaN
# k2, Tm-T                                NaN
# k3, LDH rxn                             NaN
# k4, auto-catalytic HCl production rxn   NaN
# k5, initiation rxn for HCl production   NaN
# k6, primary stabiliser rxn              NaN
# k7, radical to degraded polymer         NaN
# k8, radical to cross-link               NaN
# k9, degraded polymer effect on visc     NaN
# k10, cross-linking effect on visc       NaN
# k11, mechanical work affecting temp     NaN
# UA                                      NaN
# mu_0                                    NaN
# E                                       NaN
# q                                       NaN
# prim_stab_0                             NaN
# dtype: float64

# %% [markdown]
# Parsing filename

# %%
from os import path
all_LDH_0 = []
all_LDH_type = []

for f in files:
    direct, filename = path.split(f)
    
    LDH_0, no_use, LDH_type = filename.split('_')
    LDH_type , file_type = LDH_type.split('.')
    
    all_LDH_0 = append(all_LDH_0, LDH_0)
    all_LDH_type = append(all_LDH_type, LDH_type)

# %%
para_frame['LDH type'] = all_LDH_type
para_frame['initial LDH'] = all_LDH_0
para_frame.to_csv('test.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1366035d2037> in <module>()
# ----> 1 para_frame['LDH type'] = all_LDH_type
#       2 para_frame['initial LDH'] = all_LDH_0
#       3 para_frame.to_csv('test.csv')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    1885         else:
#    1886             # set column
# -> 1887             self._set_item(key, value)
#    1888
#    1889     def _setitem_slice(self, key, value):
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in _set_item(self, key, value)
#    1965         is_existing = key in self.columns
#    1966         self._ensure_valid_index(value)
# -> 1967         value = self._sanitize_column(key, value)
#    1968         NDFrame._set_item(self, key, value)
#    1969
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in _sanitize_column(self, key, value)
#    2015         elif isinstance(value, Index) or _is_sequence(value):
#    2016             if len(value) != len(self.index):
# -> 2017                 raise ValueError('Length of values does not match length of '
#    2018                                  'index')
#    2019
#
# ValueError: Length of values does not match length of index
