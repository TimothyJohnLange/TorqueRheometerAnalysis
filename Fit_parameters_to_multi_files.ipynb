# %% [markdown]
# ## Looping over data files and fitting parameters

# %%
from datahandling import DataFile, alldatafiles, cuts, trim
from lmfit import minimize, report_fit
from model_parameters import parameters, parameter_vectors
from curve_func_2 import torque_curve, fcn2min_torque, model_curves
from time import time as tm
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Loading all files

# %%
files = alldatafiles()
no_files = len(files)
no_files
# Out:
# 113

# %% [markdown]
# #### Looping over files

# %%
t = tm()
all_ps = []

for i in range(3):
    time_data, temp_data, torque_data = DataFile(files[i]).simple_data()
    
    # Trimming data
    c = cuts(torque_data)
    time_data = trim(time_data, c)
    temp_data = trim(temp_data, c)
    torque_data = trim(torque_data, c)
    
    # Initialising and limiting parameters
    p = parameters()
    
    # Fitting data
    result = minimize(fcn2min_torque, p, args=(time_data, torque_data))
    
    #Storing parameter values
    all_ps = append(all_ps, p)
    print 'Completed Fit ',(i + 1)
    print '__________________________'

elapsed = tm() - t
print '*******************'
print 'elapsed time (min) =', elapsed/60.
# Out:
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Completed Fit
#  1
# __________________________
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Completed Fit
#  2
# __________________________
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Completed Fit
#  3
# __________________________
# *******************
# elapsed time (min) = 1.0240500013

# %% [markdown]
# #### Analysing results

# %%
spec_result = 1
report_fit(all_ps[spec_result], show_correl=False)
# Out:
# [[Variables]]
#      E:               6370.784 +/- 57.35254 (0.90%) initial =  6500
#      UA:              329.6271 +/- 36.23312 (10.99%) initial =  340
#      k1:              1.95009 +/- 0.9224174 (47.30%) initial =  2
#      k10:             2.644553 +/- 0.3984191 (15.07%) initial =  2
#      k11:             1.153697 +/- 1.111394 (96.33%) initial =  1
#      k2:              12761.86 +/- 8784.729 (68.84%) initial =  5
#      k3:              0.3495113 +/- 0.08041396 (23.01%) initial =  0.35
#      k4:              0.2921872 +/- 0.03524487 (12.06%) initial =  0.3
#      k5:              0.0009972726 +/- 0.0001834075 (18.39%) initial =  0.001
#      k6:              1.829827 +/- 0.3240731 (17.71%) initial =  1
#      k7:              0.09628256 +/- 0.02713617 (28.18%) initial =  0.1
#      k8:              0.08009969 +/- 0.02158363 (26.95%) initial =  0.05
#      k9:              2.015174 +/- 0.8222403 (40.80%) initial =  2
#      mu_0:            0.02855905 +/- 0.01375934 (48.18%) initial =  0.03
#      prim_stab_0:     0.6726286 +/- 0.02680371 (3.98%) initial =  0.7
#      q:               2.995362 +/- 0.5879824 (19.63%) initial =  2.5

# %% [markdown]
# #### Generating and plotting all model outputs

# %%
time_data, temp_data, torque_data = DataFile(files[spec_result]).simple_data()

c_1 = cuts(torque_data)
time_data = trim(time_data, c_1)
temp_data = trim(temp_data, c_1)
torque_data = trim(torque_data, c_1)

curves = model_curves(all_ps[spec_result], time_data)

# %%
HCl, LDH, poly_act, radical, prim_stab, deg_poly, x_link, T, Tm, mu, torque = curves

# %%
figure()
plot(time_data, torque, label='fitted torque curve')
plot(time_data, torque_data, label='torque data')
legend()

figure()
plot(time_data, Tm, label='fitted temp curve')
plot(time_data, temp_data, label='temp data')
legend()
xlim([0, 31])

figure()
plot(time_data, HCl, '--', label='HCl')
plot(time_data, LDH, label='LDH')
#plot(time_data, poly_act, '-.', label='poly_act')
plot(time_data, radical, ':', label='radical')
plot(time_data, prim_stab, '--', label='prim_stab')
plot(time_data, deg_poly, label='deg_poly')
plot(time_data, x_link, label='x_link')
legend()
xlim([0, 26])
# Out:
# (0, 26)

# %% [markdown]
# #### Generating parameter vectors and plotting

# %%
para_V = parameter_vectors(all_ps)

# %%
k1_all, k2_all, k3_all, k4_all, k5_all, k6_all, k7_all, k8_all, k9_all, k10_all, k11_all, UA_all, mu_0_all, q_all, prim_stab_0_all = para_V

# %%
figure_headings = ['k1, visc-torque',
                   'k2, Tm-T',
                   'k3, LDH rxn',
                   'k4, auto-catalytic HCl production rxn',
                   'k5, initiation rxn for HCl production',
                   'k6, primary stabiliser rxn',
                   'k7, radical to degraded polymer',
                   'k8, radical to cross-link',
                   'k9, degraded polymer effect on visc',
                   'k10, cross-linking effect on visc',
                   'k11, mechanical work affecting temp',
                   'UA',
                   'mu_0',
                   'q',
                   'prim_stab_0']

# %%
for h, ps in zip(figure_headings, para_V):
    figure().suptitle(h)
    plot(ps, '.')

# %% [markdown]
# ####Placing parameters into DataFrame

# %%
from pandas import DataFrame

# %%
para_frame = DataFrame.from_records(para_V, index=figure_headings).transpose()
para_frame
# Out:
#    k1, visc-torque      k2, Tm-T  k3, LDH rxn  \
# 0         2.125578  10343.509396     0.358237
# 1         1.950090  12761.864383     0.349511
# 2         1.672427  22581.630117     0.355680
#
#    k4, auto-catalytic HCl production rxn  \
# 0                               0.295728
# 1                               0.292187
# 2                               0.292274
#
#    k5, initiation rxn for HCl production  k6, primary stabiliser rxn  \
# 0                               0.000995                    1.762435
# 1                               0.000997                    1.829827
# 2                               0.000804                    1.253882
#
#    k7, radical to degraded polymer  k8, radical to cross-link  \
# 0                         0.105783                   0.093660
# 1                         0.096283                   0.080100
# 2                         0.051175                   0.158248
#
#    k9, degraded polymer effect on visc  k10, cross-linking effect on visc  \
# 0                             1.938625                           3.649558
# 1                             2.015174                           2.644553
# 2                             1.445666                           3.024434
#
#    k11, mechanical work affecting temp          UA      mu_0         q  \
# 0                             1.086135  300.896859  0.030263  4.002752
# 1                             1.153697  329.627116  0.028559  2.995362
# 2                             1.212702  256.050289  0.049344  3.095620
#
#    prim_stab_0
# 0     0.669376
# 1     0.672629
# 2     0.908169
#
# [3 rows x 15 columns]

# %% [markdown]
# Parsing filename

# %%
from os import path
all_LDH_0 = []
all_LDH_type = []

for f in files:
    direct, filename = path.split(f)
    
    LDH_0, no_use, LDH_type = filename.split('_')
    LDH_type , file_type = LDH_type.split('.')
    
    all_LDH_0 = append(all_LDH_0, LDH_0)
    all_LDH_type = append(all_LDH_type, LDH_type)

# %% [markdown]
# Placing LDH type and initial LDH into DataFrame

# %%
all_LDH_type_frame = DataFrame(all_LDH_type, columns=(['LDH type']))
all_LDH_0_frame = DataFrame(all_LDH_0, columns=(['initial LDH']))

# %% [markdown]
# Appending LDH type and initial LDH DataFrames to parameter DataFrame. The cell in the DataFrame displays NaN. I don't know why this is happening

# %%
data_frame = para_frame.append(all_LDH_0_frame).append(all_LDH_type_frame)
data_frame
# Out:
#    LDH type          UA initial LDH  k1, visc-torque  \
# 0       NaN  300.896859         NaN         2.125578
# 1       NaN  329.627116         NaN         1.950090
# 2       NaN  256.050289         NaN         1.672427
# 0       NaN         NaN          03              NaN
# 1       NaN         NaN          03              NaN
# 2       NaN         NaN          03              NaN
# 3       NaN         NaN          03              NaN
# 4       NaN         NaN          03              NaN
# 5       NaN         NaN          03              NaN
# 6       NaN         NaN          03              NaN
# 7       NaN         NaN          03              NaN
# 8       NaN         NaN          03              NaN
# 9       NaN         NaN          03              NaN
# 10      NaN         NaN          03              NaN
# 11      NaN         NaN          03              NaN
# 12      NaN         NaN          03              NaN
# 13      NaN         NaN          03              NaN
# 14      NaN         NaN          03              NaN
# 15      NaN         NaN          03              NaN
# 16      NaN         NaN          03              NaN
# 17      NaN         NaN          03              NaN
# 18      NaN         NaN          03              NaN
# 19      NaN         NaN          03              NaN
# 20      NaN         NaN          03              NaN
# 21      NaN         NaN          03              NaN
# 22      NaN         NaN          03              NaN
# 23      NaN         NaN          03              NaN
# 24      NaN         NaN          03              NaN
# 25      NaN         NaN          03              NaN
# 26      NaN         NaN          03              NaN
# 27      NaN         NaN          05              NaN
# 28      NaN         NaN          05              NaN
# 29      NaN         NaN          05              NaN
# 30      NaN         NaN          05              NaN
# 31      NaN         NaN          05              NaN
# 32      NaN         NaN          05              NaN
# 33      NaN         NaN          05              NaN
# 34      NaN         NaN          05              NaN
# 35      NaN         NaN          05              NaN
# 36      NaN         NaN          05              NaN
# 37      NaN         NaN          05              NaN
# 38      NaN         NaN          05              NaN
# 39      NaN         NaN          05              NaN
# 40      NaN         NaN          05              NaN
# 41      NaN         NaN          05              NaN
# 42      NaN         NaN          05              NaN
# 43      NaN         NaN          05              NaN
# 44      NaN         NaN          05              NaN
# 45      NaN         NaN          05              NaN
# 46      NaN         NaN          05              NaN
# 47      NaN         NaN          05              NaN
# 48      NaN         NaN          05              NaN
# 49      NaN         NaN           1              NaN
# 50      NaN         NaN           1              NaN
# 51      NaN         NaN           1              NaN
# 52      NaN         NaN           1              NaN
# 53      NaN         NaN           1              NaN
# 54      NaN         NaN           1              NaN
# 55      NaN         NaN           1              NaN
# 56      NaN         NaN           1              NaN
#         ...         ...         ...              ...
#
#     k10, cross-linking effect on visc  k11, mechanical work affecting temp  \
# 0                            3.649558                             1.086135
# 1                            2.644553                             1.153697
# 2                            3.024434                             1.212702
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
# 10                                NaN                                  NaN
# 11                                NaN                                  NaN
# 12                                NaN                                  NaN
# 13                                NaN                                  NaN
# 14                                NaN                                  NaN
# 15                                NaN                                  NaN
# 16                                NaN                                  NaN
# 17                                NaN                                  NaN
# 18                                NaN                                  NaN
# 19                                NaN                                  NaN
# 20                                NaN                                  NaN
# 21                                NaN                                  NaN
# 22                                NaN                                  NaN
# 23                                NaN                                  NaN
# 24                                NaN                                  NaN
# 25                                NaN                                  NaN
# 26                                NaN                                  NaN
# 27                                NaN                                  NaN
# 28                                NaN                                  NaN
# 29                                NaN                                  NaN
# 30                                NaN                                  NaN
# 31                                NaN                                  NaN
# 32                                NaN                                  NaN
# 33                                NaN                                  NaN
# 34                                NaN                                  NaN
# 35                                NaN                                  NaN
# 36                                NaN                                  NaN
# 37                                NaN                                  NaN
# 38                                NaN                                  NaN
# 39                                NaN                                  NaN
# 40                                NaN                                  NaN
# 41                                NaN                                  NaN
# 42                                NaN                                  NaN
# 43                                NaN                                  NaN
# 44                                NaN                                  NaN
# 45                                NaN                                  NaN
# 46                                NaN                                  NaN
# 47                                NaN                                  NaN
# 48                                NaN                                  NaN
# 49                                NaN                                  NaN
# 50                                NaN                                  NaN
# 51                                NaN                                  NaN
# 52                                NaN                                  NaN
# 53                                NaN                                  NaN
# 54                                NaN                                  NaN
# 55                                NaN                                  NaN
# 56                                NaN                                  NaN
#                                   ...                                  ...
#
#         k2, Tm-T  k3, LDH rxn  k4, auto-catalytic HCl production rxn  \
# 0   10343.509396     0.358237                               0.295728
# 1   12761.864383     0.349511                               0.292187
# 2   22581.630117     0.355680                               0.292274
# 0            NaN          NaN                                    NaN
# 1            NaN          NaN                                    NaN
# 2            NaN          NaN                                    NaN
# 3            NaN          NaN                                    NaN
# 4            NaN          NaN                                    NaN
# 5            NaN          NaN                                    NaN
# 6            NaN          NaN                                    NaN
# 7            NaN          NaN                                    NaN
# 8            NaN          NaN                                    NaN
# 9            NaN          NaN                                    NaN
# 10           NaN          NaN                                    NaN
# 11           NaN          NaN                                    NaN
# 12           NaN          NaN                                    NaN
# 13           NaN          NaN                                    NaN
# 14           NaN          NaN                                    NaN
# 15           NaN          NaN                                    NaN
# 16           NaN          NaN                                    NaN
# 17           NaN          NaN                                    NaN
# 18           NaN          NaN                                    NaN
# 19           NaN          NaN                                    NaN
# 20           NaN          NaN                                    NaN
# 21           NaN          NaN                                    NaN
# 22           NaN          NaN                                    NaN
# 23           NaN          NaN                                    NaN
# 24           NaN          NaN                                    NaN
# 25           NaN          NaN                                    NaN
# 26           NaN          NaN                                    NaN
# 27           NaN          NaN                                    NaN
# 28           NaN          NaN                                    NaN
# 29           NaN          NaN                                    NaN
# 30           NaN          NaN                                    NaN
# 31           NaN          NaN                                    NaN
# 32           NaN          NaN                                    NaN
# 33           NaN          NaN                                    NaN
# 34           NaN          NaN                                    NaN
# 35           NaN          NaN                                    NaN
# 36           NaN          NaN                                    NaN
# 37           NaN          NaN                                    NaN
# 38           NaN          NaN                                    NaN
# 39           NaN          NaN                                    NaN
# 40           NaN          NaN                                    NaN
# 41           NaN          NaN                                    NaN
# 42           NaN          NaN                                    NaN
# 43           NaN          NaN                                    NaN
# 44           NaN          NaN                                    NaN
# 45           NaN          NaN                                    NaN
# 46           NaN          NaN                                    NaN
# 47           NaN          NaN                                    NaN
# 48           NaN          NaN                                    NaN
# 49           NaN          NaN                                    NaN
# 50           NaN          NaN                                    NaN
# 51           NaN          NaN                                    NaN
# 52           NaN          NaN                                    NaN
# 53           NaN          NaN                                    NaN
# 54           NaN          NaN                                    NaN
# 55           NaN          NaN                                    NaN
# 56           NaN          NaN                                    NaN
#              ...          ...                                    ...
#
#     k5, initiation rxn for HCl production  k6, primary stabiliser rxn  \
# 0                                0.000995                    1.762435
# 1                                0.000997                    1.829827
# 2                                0.000804                    1.253882
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
# 5                                     NaN                         NaN
# 6                                     NaN                         NaN
# 7                                     NaN                         NaN
# 8                                     NaN                         NaN
# 9                                     NaN                         NaN
# 10                                    NaN                         NaN
# 11                                    NaN                         NaN
# 12                                    NaN                         NaN
# 13                                    NaN                         NaN
# 14                                    NaN                         NaN
# 15                                    NaN                         NaN
# 16                                    NaN                         NaN
# 17                                    NaN                         NaN
# 18                                    NaN                         NaN
# 19                                    NaN                         NaN
# 20                                    NaN                         NaN
# 21                                    NaN                         NaN
# 22                                    NaN                         NaN
# 23                                    NaN                         NaN
# 24                                    NaN                         NaN
# 25                                    NaN                         NaN
# 26                                    NaN                         NaN
# 27                                    NaN                         NaN
# 28                                    NaN                         NaN
# 29                                    NaN                         NaN
# 30                                    NaN                         NaN
# 31                                    NaN                         NaN
# 32                                    NaN                         NaN
# 33                                    NaN                         NaN
# 34                                    NaN                         NaN
# 35                                    NaN                         NaN
# 36                                    NaN                         NaN
# 37                                    NaN                         NaN
# 38                                    NaN                         NaN
# 39                                    NaN                         NaN
# 40                                    NaN                         NaN
# 41                                    NaN                         NaN
# 42                                    NaN                         NaN
# 43                                    NaN                         NaN
# 44                                    NaN                         NaN
# 45                                    NaN                         NaN
# 46                                    NaN                         NaN
# 47                                    NaN                         NaN
# 48                                    NaN                         NaN
# 49                                    NaN                         NaN
# 50                                    NaN                         NaN
# 51                                    NaN                         NaN
# 52                                    NaN                         NaN
# 53                                    NaN                         NaN
# 54                                    NaN                         NaN
# 55                                    NaN                         NaN
# 56                                    NaN                         NaN
#                                       ...                         ...
#
#     k7, radical to degraded polymer  k8, radical to cross-link  \
# 0                          0.105783                   0.093660
# 1                          0.096283                   0.080100
# 2                          0.051175                   0.158248
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# 5                               NaN                        NaN
# 6                               NaN                        NaN
# 7                               NaN                        NaN
# 8                               NaN                        NaN
# 9                               NaN                        NaN
# 10                              NaN                        NaN
# 11                              NaN                        NaN
# 12                              NaN                        NaN
# 13                              NaN                        NaN
# 14                              NaN                        NaN
# 15                              NaN                        NaN
# 16                              NaN                        NaN
# 17                              NaN                        NaN
# 18                              NaN                        NaN
# 19                              NaN                        NaN
# 20                              NaN                        NaN
# 21                              NaN                        NaN
# 22                              NaN                        NaN
# 23                              NaN                        NaN
# 24                              NaN                        NaN
# 25                              NaN                        NaN
# 26                              NaN                        NaN
# 27                              NaN                        NaN
# 28                              NaN                        NaN
# 29                              NaN                        NaN
# 30                              NaN                        NaN
# 31                              NaN                        NaN
# 32                              NaN                        NaN
# 33                              NaN                        NaN
# 34                              NaN                        NaN
# 35                              NaN                        NaN
# 36                              NaN                        NaN
# 37                              NaN                        NaN
# 38                              NaN                        NaN
# 39                              NaN                        NaN
# 40                              NaN                        NaN
# 41                              NaN                        NaN
# 42                              NaN                        NaN
# 43                              NaN                        NaN
# 44                              NaN                        NaN
# 45                              NaN                        NaN
# 46                              NaN                        NaN
# 47                              NaN                        NaN
# 48                              NaN                        NaN
# 49                              NaN                        NaN
# 50                              NaN                        NaN
# 51                              NaN                        NaN
# 52                              NaN                        NaN
# 53                              NaN                        NaN
# 54                              NaN                        NaN
# 55                              NaN                        NaN
# 56                              NaN                        NaN
#                                 ...                        ...
#
#     k9, degraded polymer effect on visc      mu_0  prim_stab_0         q
# 0                              1.938625  0.030263     0.669376  4.002752
# 1                              2.015174  0.028559     0.672629  2.995362
# 2                              1.445666  0.049344     0.908169  3.095620
# 0                                   NaN       NaN          NaN       NaN
# 1                                   NaN       NaN          NaN       NaN
# 2                                   NaN       NaN          NaN       NaN
# 3                                   NaN       NaN          NaN       NaN
# 4                                   NaN       NaN          NaN       NaN
# 5                                   NaN       NaN          NaN       NaN
# 6                                   NaN       NaN          NaN       NaN
# 7                                   NaN       NaN          NaN       NaN
# 8                                   NaN       NaN          NaN       NaN
# 9                                   NaN       NaN          NaN       NaN
# 10                                  NaN       NaN          NaN       NaN
# 11                                  NaN       NaN          NaN       NaN
# 12                                  NaN       NaN          NaN       NaN
# 13                                  NaN       NaN          NaN       NaN
# 14                                  NaN       NaN          NaN       NaN
# 15                                  NaN       NaN          NaN       NaN
# 16                                  NaN       NaN          NaN       NaN
# 17                                  NaN       NaN          NaN       NaN
# 18                                  NaN       NaN          NaN       NaN
# 19                                  NaN       NaN          NaN       NaN
# 20                                  NaN       NaN          NaN       NaN
# 21                                  NaN       NaN          NaN       NaN
# 22                                  NaN       NaN          NaN       NaN
# 23                                  NaN       NaN          NaN       NaN
# 24                                  NaN       NaN          NaN       NaN
# 25                                  NaN       NaN          NaN       NaN
# 26                                  NaN       NaN          NaN       NaN
# 27                                  NaN       NaN          NaN       NaN
# 28                                  NaN       NaN          NaN       NaN
# 29                                  NaN       NaN          NaN       NaN
# 30                                  NaN       NaN          NaN       NaN
# 31                                  NaN       NaN          NaN       NaN
# 32                                  NaN       NaN          NaN       NaN
# 33                                  NaN       NaN          NaN       NaN
# 34                                  NaN       NaN          NaN       NaN
# 35                                  NaN       NaN          NaN       NaN
# 36                                  NaN       NaN          NaN       NaN
# 37                                  NaN       NaN          NaN       NaN
# 38                                  NaN       NaN          NaN       NaN
# 39                                  NaN       NaN          NaN       NaN
# 40                                  NaN       NaN          NaN       NaN
# 41                                  NaN       NaN          NaN       NaN
# 42                                  NaN       NaN          NaN       NaN
# 43                                  NaN       NaN          NaN       NaN
# 44                                  NaN       NaN          NaN       NaN
# 45                                  NaN       NaN          NaN       NaN
# 46                                  NaN       NaN          NaN       NaN
# 47                                  NaN       NaN          NaN       NaN
# 48                                  NaN       NaN          NaN       NaN
# 49                                  NaN       NaN          NaN       NaN
# 50                                  NaN       NaN          NaN       NaN
# 51                                  NaN       NaN          NaN       NaN
# 52                                  NaN       NaN          NaN       NaN
# 53                                  NaN       NaN          NaN       NaN
# 54                                  NaN       NaN          NaN       NaN
# 55                                  NaN       NaN          NaN       NaN
# 56                                  NaN       NaN          NaN       NaN
#                                     ...       ...          ...       ...
#
# [229 rows x 17 columns]

# %%
data_frame.at[0, 'initial LDH']
# Out:
# array([nan, u'03', nan], dtype=object)

# %%
data_frame.at[0, 'LDH type']
# Out:
# array([nan, nan, u'Actilox'], dtype=object)
