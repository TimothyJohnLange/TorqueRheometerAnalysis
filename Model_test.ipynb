# %%
from model_parameters import parameters
from curve_func_2 import model_curves
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#          k1   k2    k3   k4   k5    k6    k7   k8   k9    k10  k11  UA     mu_0    E       q    ps0  LDH
ini_val = [1.9, 30.0, 10.0, 1.0, 0.01, 20.0, 0.3, 0.1, 1.0, 2.0, 2.6, 300.0, 0.0372, 6208.6, 2.5, 1.3, 0.6]

# %%
p = parameters(ini_val)

# %%
time_data = linspace(0, 100, 200)

# %%
curves = model_curves(p, time_data)
HCl, LDH, poly_act, radical, prim_stab, deg_poly, x_link, T, Tm, mu, torque = curves

# %%
figure() 
#plot(time_data, poly_act, '-.', label='poly_act', lw='2')
plot(time_data, radical, '--', label='Radical', lw='2')
plot(time_data, prim_stab, ':', label='Primary stabiliser', lw='2')
plot(time_data, LDH, label='LDH', lw='2')
plot(time_data, HCl, '-.', label='HCl', lw='2')
plot(time_data, deg_poly, '--', label='Degraded polymer', lw='2')
plot(time_data, x_link, ':', label='Cross-link', lw='2')
xlabel('Time (min)')
ylabel('Concentration (phr)')
legend(loc='upper left')
#ylim([0, 1.4])
#xlim([0, 15])

figure()
plot(time_data, torque)

# %%
plot?
